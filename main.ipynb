# %%
from google.colab.patches import cv2_imshow
import cv2


image = cv2.imread('test_image.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

ret, thresh = cv.threshold(imgray, 127, 255, 0)

countours, hierarchy = cv2.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# нужно раскомментировать, чтобы на изображении нарисовались контуры
# cv2.drawContours(gray_image, countours, -1, (0, 255, 0), 3)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1010x758 at 0x7F5A6A7C8550>
