# %% [markdown]
# <a href="https://colab.research.google.com/github/OSLL/sirius-cv/blob/12_Daniil_Komarov_object_detection/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
# !wget https://lh3.googleusercontent.com/proxy/6xW1K95-G0KoTG8A09MVAVO-ZuxUUlYFGGRs_tW_4Az2oaa0Rez3cFOmsFHXwbMxYTsKxu8cHQ69uYRU65BUtlNZfGsNC25KZ_XCXPndZnuQxkvM-RDbizgeEtDIC5MPlXqVlg -O to_find.jpg
img1 = cv.imread('/content/to_find.jpg',cv.IMREAD_GRAYSCALE)

# !wget https://cdn.tvc.ru/pictures/o/277/499.jpg -O picture.jpg
img2 = cv.imread('/content/picture.jpg',cv.IMREAD_GRAYSCALE)

orb = cv2.ORB_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matches = bf.match(des1,des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# Draw first 10 matches.
cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], result, flags=2)
cv2_imshow(result)
# Out:
# --2020-10-21 15:22:03--  https://lh3.googleusercontent.com/proxy/6xW1K95-G0KoTG8A09MVAVO-ZuxUUlYFGGRs_tW_4Az2oaa0Rez3cFOmsFHXwbMxYTsKxu8cHQ69uYRU65BUtlNZfGsNC25KZ_XCXPndZnuQxkvM-RDbizgeEtDIC5MPlXqVlg
# Resolving lh3.googleusercontent.com (lh3.googleusercontent.com)... 108.177.120.132, 2607:f8b0:4001:c03::84
# Connecting to lh3.googleusercontent.com (lh3.googleusercontent.com)|108.177.120.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43715 (43K) [image/jpeg]
# Saving to: ‘to_find.jpg’
#
# to_find.jpg         100%[===================>]  42.69K  --.-KB/s    in 0s
#
# 2020-10-21 15:22:03 (94.3 MB/s) - ‘to_find.jpg’ saved [43715/43715]
#
# --2020-10-21 15:22:03--  https://cdn.tvc.ru/pictures/o/277/499.jpg
# Resolving cdn.tvc.ru (cdn.tvc.ru)... 5.254.23.88
# Connecting to cdn.tvc.ru (cdn.tvc.ru)|5.254.23.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38984 (38K) [image/jpeg]
# Saving to: ‘picture.jpg’
#
# ...
