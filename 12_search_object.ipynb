# %% [markdown]
# <a href="https://colab.research.google.com/github/OSLL/sirius-cv/blob/12_object_detection_danil_astafurov/12_search_object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://4.bp.blogspot.com/-w6sf4XrHkDQ/WPiMmnvbTuI/AAAAAAAAUxM/wokGNHvhyEU_Gcp_flDlVVkoB4xN9VKRQCEw/s1600/stop_sign_country_road.jpg

# %%
# !wget https://pixy.org/src/102/1029747.png

# %%
# !wget https://www.mos.ru/upload/newsfeed/newsfeed/photo_2017-11-17_11-03-19.jpg

# %%
# !wget https://www.люберцы.рф/sites/default/files/parkovka.jpg
# Out:
# --2020-10-12 17:38:07--  https://www.xn--90aiqw4a4aq.xn--p1ai/sites/default/files/parkovka.jpg
# Resolving www.xn--90aiqw4a4aq.xn--p1ai (www.xn--90aiqw4a4aq.xn--p1ai)... 91.218.247.188
# Connecting to www.xn--90aiqw4a4aq.xn--p1ai (www.xn--90aiqw4a4aq.xn--p1ai)|91.218.247.188|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35873 (35K) [image/jpeg]
# Saving to: ‘parkovka.jpg’
#
# parkovka.jpg        100%[===================>]  35.03K  --.-KB/s    in 0s
#
# 2020-10-12 17:38:10 (253 MB/s) - ‘parkovka.jpg’ saved [35873/35873]

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('/content/1029747.png',0)          # queryImage
img2 = cv2.imread('/content/stop_sign_country_road.jpg',0) # trainImage

# Initiate SIFT detector
orb = cv2.ORB_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matches = bf.match(des1,des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], flags=2, outImg=None)

plt.imshow(img3)
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('/content/parkovka.jpg',0)          # queryImage
img2 = cv2.imread('/content/photo_2017-11-17_11-03-19.jpg',0) # trainImage

# Initiate SIFT detector
orb = cv2.ORB_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matches = bf.match(des1,des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], flags=2, outImg=None)

plt.imshow(img3)
plt.show()

# %%
des1
# Out:
# array([[120,  48,  56, ..., 136,  70,  51],
#        [ 84, 164,  70, ...,  10, 113, 128],
#        [194, 164,  70, ...,  40,  97,   0],
#        ...,
#        [ 32,  44,   2, ...,  10,  49, 128],
#        [ 82,  32,  84, ..., 136, 115,   0],
#        [  2, 141,  10, ...,  26, 176, 136]], dtype=uint8)
