# %% [markdown]
# <a href="https://colab.research.google.com/github/OSLL/sirius-cv/blob/3_using_canny_edge_detector/3_using_canny_edge_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

# %%
from __future__ import print_function
import cv2 as cv
import argparse
from google.colab.patches import cv2_imshow
max_lowThreshold = 100
ratio = 3
kernel_size = 3
def CannyThreshold(val):
  low_threshold = val
  img_blur = cv.blur(src_gray, (3,3))
  detected_edges = cv.Canny(img_blur, low_threshold, low_threshold*ratio, kernel_size)
  mask = detected_edges != 0
  dst = src * (mask[:,:,None].astype(src.dtype))
  cv2_imshow(dst)

# %%
src = cv.imread(cv.samples.findFile('photo.jpg'))
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)

CannyThreshold(0)
cv.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=1010x758 at 0x7FCDC08F99B0>
# -1
