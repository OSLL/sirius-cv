# %% [markdown]
# <a href="https://colab.research.google.com/github/OSLL/sirius-cv/blob/2_converting_an_image_to_black_and_white/Whiteandblack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread('road.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1010x758 at 0x7F87F0940CC0>

# %% [markdown]
# # Новый раздел
